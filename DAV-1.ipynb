# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv(r"C:\Users\rajuv\Downloads\country_wise_latest.csv")

# %%
ds
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
ds.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
ds.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
ds.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
ds.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# RELATING THE VARIABLES WITH SCATTERPLOTS

# %%
sns.distplot(ds['Active'])
# Out:
# C:\Users\rajuv\AppData\Local\Temp\ipykernel_13440\1425380016.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds['Active'])
# <Axes: xlabel='Active', ylabel='Density'>

# %%
sns.relplot(x="Recovered",y="Deaths",hue="Confirmed", data=ds)

# %%
sns.pairplot(ds)

# %%
sns.relplot(x='Deaths',y='Recovered',kind='line',data=ds)

# %%
sns.catplot(x='Confirmed',y='Recovered',data=ds)

# %%
sns.barplot(x='Country/Region', y='Confirmed', data=ds)
# Out:
# <Axes: xlabel='Country/Region', ylabel='Confirmed'>

# %%
subset_ds= ds.head(5)

sns.barplot(x='Country/Region', y='Confirmed', data=subset_ds)
# Out:
# <Axes: xlabel='Country/Region', ylabel='Confirmed'>

# %%
plt.hist(ds['Confirmed'], bins=10, color='skyblue', edgecolor='black')

plt.xlabel('Confirmed Cases')
plt.ylabel('Frequency')
plt.title('Histogram of Confirmed COVID-19 Cases')

plt.show()

# %%
subset_ds= ds.head(5)


sns.scatterplot(x='Country/Region', y='Confirmed', data=subset_ds)


plt.title('Scatter Plot')

plt.show()

# %%
subset_ds = ds.head(5)

labels = subset_ds['Country/Region']
sizes = subset_ds['Confirmed']

# Create a pie chart
plt.figure(figsize=(8, 8))  
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

plt.title('Sample Pie Chart')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = subset_ds['Country/Region']
y1 = subset_ds['Confirmed']
y2 = subset_ds['Active']
y3 = subset_ds['Deaths']

# Create multiple line graph
plt.figure(figsize=(10, 6))  # Set figure size

# Plot lines
plt.plot(x, y1, marker='o', label='Confirmed')
plt.plot(x, y2, marker='s', label='Active')
plt.plot(x, y3, marker='^', label='Deaths')

# Add labels and title
plt.xlabel('Country')
plt.ylabel('Total no. of Cases')
plt.title('Multiple Line Graph')


plt.legend()


plt.grid(True) 
plt.show()
